# %%
# ============================================================
# e1 Cluster Detection Using Random Forest (R Pipeline)
# ============================================================

library(randomForest)
library(caret)
library(pROC)
set.seed(486)

# ---------------------------
# Load data
# ---------------------------
library(readr)
csv_path <- "/kaggle/input/original-training-data/Original training DB e1 positive.csv"
df <- read_csv(csv_path, show_col_types = FALSE)

label_col <- "Label"
df[[label_col]] <- factor(as.character(df[[label_col]]), levels=c("0","1"))

# %%
# ---------------------------
# Audit of Original Database
# ---------------------------

# Dimensions
cat("Number of samples:", nrow(df), "\n")
cat("Number of features (excluding label):", ncol(df) - 1, "\n")

# Class distribution
cat("\nClass distribution:\n")
print(table(df[[label_col]]))

# Check class balance
class_counts <- table(df[[label_col]])
minority_ratio <- min(class_counts) / sum(class_counts)
cat(sprintf("\nMinority class ratio: %.4f\n", minority_ratio))

# Check for missing values
cat("\nMissing values per column:\n")
print(colSums(is.na(df)))

# Data types of features
cat("\nFeature types:\n")
print(sapply(df, class))

# Ratio of samples to features
ratio <- nrow(df) / (ncol(df) - 1)
cat(sprintf("\nSamples-to-features ratio: %.2f\n", ratio))
# Out:
# Number of samples: 871
# Number of features (excluding label): 608
#
# Class distribution:
#
#   0   1
# 572 299
#
# Minority class ratio: 0.3433
#
# Missing values per column:
#        GABRG2         CELF4         SRRM4        SLC1A3        ATP1A3
#             0             0             0             0             0
#        RBFOX3        GABRA4         NHSL1        GRAMD3        SEZ6L2
#             0             0             0             0             0
#          SV2A          PON2         SCN3B       DLX6AS1           SYP
#             0             0             0             0             0
#        ELAVL2        ADAM28          BEX1         DOCK8       FAM153C
#             0             0             0             0             0
#         PWRN1         KANK1         PTPRC        ADGRG1       APBB1IP
#             0             0             0             0             0
#      SYNPRAS1        INPP5D        CSF2RA         NRIP3       HEPACAM
#             0             0             0             0             0
#          FLI1         PTPRS         PLCG2         ARL4C        MEGF10
#             0             0             0             0             0
#           GSN       COL21A1      C10ORF90       TMEM144          GAD2
#             0             0             0             0             0
#       ZCCHC24         GRIP2         S100B          CHD7         OLIG1
#             0             0             0             0             0
#         HEPN1         CECR2         TANC1          UGT8     LINC00639
#             0             0             0             0             0
#         PROX1           EGF         CALB2        TESPA1     LINC00507
#             0             0             0             0             0
#       SLC17A7        ZNF536     LINC00508      ANKRD33B     LINC00152
#             0             0             0             0             0
#          TBR1         NPTX1     LINC00710         SMAD3        KCNIP1
#             0             0             0             0             0
#    MIR44351HG        ATP1B2          NRGN        SFTA1P       SLC17A6
#             0             0             0             0             0
#     LINC01500      ELAVL2.1        BTBD11       NRIP3.1          IGF1
#             0             0             0             0             0
#        GAD2.1       PROX1.1        ADRA1A      KIAA1456       GRIP2.1
#             0             0             0             0             0
#       SLC30A3     ADCYAP1R1     ADARB2AS1          VWC2     LINC01105
#             0             0             0             0             0
#      KIAA1211          CUX2          NRN1          DLX1         TYRO3
#             0             0             0             0             0
#          ART3      KIAA1958          MGLL         GRIK3        CUX2.1
#             0             0             0             0             0
#   ADARB2AS1.1          LHX6          COBL          FLT3       PROX1.2
#             0             0             0             0             0
#      TMEM132C          EGFR         CALB1    RASGRF2AS1         TRBC2
#             0             0             0             0             0
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        RBFOX3        GABRA4         NHSL1        GRAMD3        SEZ6L2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          SV2A          PON2         SCN3B       DLX6AS1           SYP
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        ELAVL2        ADAM28          BEX1         DOCK8       FAM153C
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         PWRN1         KANK1         PTPRC        ADGRG1       APBB1IP
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      SYNPRAS1        INPP5D        CSF2RA         NRIP3       HEPACAM
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          FLI1         PTPRS         PLCG2         ARL4C        MEGF10
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#           GSN       COL21A1      C10ORF90       TMEM144          GAD2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       ZCCHC24         GRIP2         S100B          CHD7         OLIG1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         HEPN1         CECR2         TANC1          UGT8     LINC00639
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         PROX1           EGF         CALB2        TESPA1     LINC00507
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       SLC17A7        ZNF536     LINC00508      ANKRD33B     LINC00152
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          TBR1         NPTX1     LINC00710         SMAD3        KCNIP1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#    MIR44351HG        ATP1B2          NRGN        SFTA1P       SLC17A6
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#     LINC01500      ELAVL2.1        BTBD11       NRIP3.1          IGF1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        GAD2.1       PROX1.1        ADRA1A      KIAA1456       GRIP2.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       SLC30A3     ADCYAP1R1     ADARB2AS1          VWC2     LINC01105
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      KIAA1211          CUX2          NRN1          DLX1         TYRO3
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          ART3      KIAA1958          MGLL         GRIK3        CUX2.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#   ADARB2AS1.1          LHX6          COBL          FLT3       PROX1.2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      TMEM132C          EGFR         CALB1    RASGRF2AS1         TRBC2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         RSPO2         MAPK4          NFIX         NR2F2      NR2F2AS1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         CMTM8        SEMA3A       CNTNAP3           KIT         KITLG
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         PRKCQ          KAL1       CALB2.1          TOX2        TRIM36
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       SLITRK2           SST          PKP2     LINC00472         MAML3
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      TMEM200C         XYLT1     LINC01102          FIGN         NXPH2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         PREX2      ADAMTS17      PROX1AS1          UTRN        ADRA1B
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#     LINC01411         EGF.1        CHD7.1         MYO16        TOX2.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         LAMP5        SPHKAP        UTRN.1       ST6GAL2       NXPH2.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         TRPC3      ADRA1B.1       STARD13    SYNPRAS1.1        CHST15
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          FAT1          CDH7       CALB2.2        KAL1.1         CPLX3
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        BCL11B    TMEM132C.1        TGFBR2          CLMP        PAPSS2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#           VIP         ADCY8      ARHGAP28    CSGALNACT1          TOX3
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        COL5A2         SLIT3        MPPED1       FAM19A4        CHRNB3
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PAX6         PTHLH         SYT10      ARHGAP18        CHRNA2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      KIAA1644          TLE2      INHBAAS1        ADAM33          GRPR
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          LHFP          CD36        C8ORF4    ZNF385DAS2        PKP2.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#    TMEM200C.1         BAGE2        PCDH18         ASIC4      SERPINE2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          BCHE        CHD7.2           DCN     ZBTB20AS1        FAM46A
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         EGF.2          VWDE   LINC01411.1        UTRN.2        PAX6.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          WIF1          SOX5     LINC00856         CHRM2        HCRTR2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        PTPRZ1   ADAMTS9.AS2         DCN.1    TMEM200C.2        BCL11A
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      MPPED1.1      PAPSS2.1        PDZRN4         CBLN4         ABCB5
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        IGSF21        OSBPL3       COL16A1    KIAA1644.1       PRELID2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      TGFBR2.1         EPHB6           PTN           SP8        BCHE.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          PBX3          LGI2       TRPC3.1        POU6F2           TOX
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#    SERPINE2.1      NRG1.IT1         NTNG1          TNS3      C8ORF4.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      COL5A2.1  ARHGEF26.AS1        FRMPD1       NTNG1.1      COL5A2.2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         LIN7A        PKP2.2           CA2         TOX.1          NDNF
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#           MAF        PLCXD3      ARHGAP31          NPNT         LAMA3
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       NR2F2.1     LINC01197       ST3GAL1        PRSS12        IL1RAP
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         SSTR2         VAT1L          NFIA         ITGB5         MAML2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         IGSF3   SYNPR.AS1.2          PNOC           CA3       TMEM196
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         SOX13          RIN2         EGF.3        SEMA5A   LINC01411.2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        SOX5.1       COL19A1        CHD7.3         EPHA4  CSGALNACT1.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         HTR2C        VWDE.1      ARHGAP42        PTCHD4  ZBTB20.AS1.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        NKAIN3        IQGAP2      BCL11B.1         PTGFR        SEMA3C
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        LRRC3B        PLXNA4        NECAB1        NPFFR1       COL12A1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        LGI2.1        GPR149        LYPD6B         TBL1X         DCN.2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         KIT.1         SAMD5         OPRK1      CHRNA2.1          NPR3
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         MCTP2          MC4R       BAGE2.1     VWC2L.IT1        ANGPT1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         KCNK2      HCRTR2.1         BCAS1        WIF1.1     LINC01435
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        CXCL12      FAM46A.1        NDNF.1      ADAM33.1      CHRNB3.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        TNS3.1       TSPAN12           CA8         PTGDS         HIF3A
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          SNCG         EDNRA         MMRN2      PTPRZ1.1      LRRC3B.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         CNTN6         VIP.1       ST8SIA5     FAM19A4.1       PTHLH.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        IGFBP5     SLITRK2.1      BCL11B.2           ID2      SEMA3C.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       KCNK2.1        DPYSL3    ARHGAP42.1       TBL1X.1          DPF3
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        LHFP.1      CHRNA2.2          TAC3     COL16A1.1        NDNF.2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        ZBTB18      POU6F2.1      IQGAP2.1       FAM135B      PPAPDC1A
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       EPHB6.1         DISC1        SNCG.1       SLIT3.1           WLS
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      ARHGAP36        SLC7A2      HCRTR2.2       MMRN2.1         MYO1B
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        STXBP6       SAMD5.1         DCN.3       LAMA3.1        FAM84A
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       MCTP2.1        WIF1.2     LINC00595        PNOC.1       BCAS1.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       BAGE2.2        TOX3.1         SCN7A        LGI2.2     TSPAN12.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         CA2.1      FAM46A.2  CSGALNACT1.2        MC4R.1        SLC5A8
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       FAM196A         SCML4      ANGPT1.1         VIP.2           CRH
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        WIF1.3      STXBP6.1      PLCXD3.1       SLIT3.2         FGFR2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       LAMA3.2     FAM196A.1     TSPAN12.2         DOCK1     PCDH9.AS1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      HCRTR2.3      SEMA3C.2         DCN.4    PPAPDC1A.1      FAM46A.3
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       EPHB6.2       HIF3A.1        ATP2B4        SRGAP1      PLXNA4.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      PTCHD4.1      ADAM33.2         HLA.B        TOX3.2         HLA.C
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      BCL11A.1 ZNF385D.AS2.1    ARHGAP36.1         GREM2         FOXO1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       BCAS1.2       BAGE2.3        MC4R.2      PCDH18.1      PLXNA4.2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      ADAM33.3    ARHGAP36.2   LINC01435.1       BCAS1.3         UNC5B
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       BAGE2.4       GREM2.1        MC4R.3    ARHGAP18.1          ANK1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       HLA.B.1         HSPB8           B2M      PCDH18.2         RAMP1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       SAMD5.2       ASIC4.1         GLIS3       ADCY8.1      ARHGEF28
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#  CSGALNACT1.3        ATP11C  ZBTB20.AS1.2       TPD52L1          GNG4
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      IQGAP2.2         DCHS2      BCL11A.2      TMEM178A     LINC00923
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#           KMO     TMEM196.1         PLCE1        LHFP.2           ELN
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      TRIM36.1       PTGDS.1      ARHGAP29         DGCR5         GPR39
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       MCTP2.2        TAC3.1       CHRM2.1       SCN7A.1   VWC2L.IT1.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      CXCL12.1       LAMA3.3          CDK6        GRIN3A       TBL1X.2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         RGS16       SCML4.1         CA8.1       MMRN2.2    ARHGAP18.2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         RAB37          RGS8       EDNRA.1        SNCG.2         GAP43
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       MMRN2.3        SNCG.3       LAMA3.4          NRP2      PCDH18.3
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       EDNRA.2       SCML4.2        PNOC.2      ADAM28.1     APBB1IP.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      CSF2RA.1      INPP5D.1       PTPRC.1        CX3CR1          CD53
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       PLCG2.1         IKZF1        FLI1.1         ITGAX         PTN.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        MS4A6E          C1QC        SAMSN1           SYK         MS4A7
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#     LINC00996        MS4A14          FGD2        TYROBP     HEPACAM.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       HEPN1.1          LRP4       PTGDS.2         HIP1R     LINC00511
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        PLXNB3          APOD       S100B.1       PTPRS.1      MEGF10.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#     PCDH9.AS3       OLIG1.1       GPR37L1       BCAS1.4      LRP4.AS1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        UGT8.1   LINC00639.1    C10ORF90.1        CARNS1          MOBP
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        SOX5.2          ST18         CNDP1       FAM107B        CERCAM
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         FOLH1          CD22           MOG        RNASE1          SPP1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        OPALIN           MAG       NHSL1.1         ABCA8          MYRF
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#   LINC00511.1          ERMN         NINJ2        NOTCH2        ATP1A2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        MTSS1L         TMCC3          BCAN          TMC6        BRINP1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#      PRICKLE2         TOX.2        TTTY14    LRP4.AS1.1      ADGRG1.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        TNS3.2    ARHGAP42.2       ADCY8.2   FAM155A.IT1       C1ORF21
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         GPNMB     LINC00499           MAL        MEGF11   LINC00499.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       COL20A1        APOD.1         DAAM2         PAPLN       RANBP3L
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#       OLIG1.2         PAMR1        COL9A1         SCN3A       GPNMB.1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#          RORB        STK32A       SLCO1C1        SHISA9          GLI3
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#    LHFPL3.AS1       SLC7A11           EZR      SLC25A18       ALDH1L1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        UGT8.2         OLIG2        BCHE.2       BCAS1.5        ETNPPL
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#        EMX2OS         KLRC3      FAM189A2         PRODH        FERMT1
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         CSPG4          GJA1         LAMA1          YAP1   LINC00639.2
#     "numeric"     "numeric"     "numeric"     "numeric"     "numeric"
#         SMOC1     LINC00498         GFRA1         Label
#     "numeric"     "numeric"     "numeric"      "factor"
#
# Samples-to-features ratio: 1.43

# %%
# ---------------------------
# Train / Verification Split
# ---------------------------
set.seed(486)
pick_one <- function(x, lab) sample(which(x == lab), 1)
i_pos <- pick_one(df[[label_col]], "1")
i_neg <- pick_one(df[[label_col]], "0")
verif_idx <- c(i_pos, i_neg)

verif_df <- df[verif_idx, ]
train_df <- df[-verif_idx, ]

# %%
# ---------------------------
# 2) Define hyperparameter grid
# ---------------------------
p <- ncol(train_df) - 1   # exclude label
mtry_grid  <- unique(round(c(0.5*sqrt(p), sqrt(p), 2*sqrt(p))))
ntree_grid <- c(100, 500, 1000, 2000, 4000, 8000)
cut_grid   <- list(c(0.3,0.7), c(0.5,0.5), c(0.7,0.3))

results <- data.frame(ntree=integer(), mtry=integer(),
                      cutoff=I(list()), OOB=numeric())

best <- list(oob=Inf)

# %%
# ---------------------------
# Training / Verification DB Summaries
# ---------------------------
cat("\n--- Training DB Summary ---\n")
cat("Samples:", nrow(train_df), " | Features:", ncol(train_df) - 1, "\n")
print(table(train_df[[label_col]]))
cat(sprintf("Minority class ratio: %.4f\n",
            min(table(train_df[[label_col]])) / nrow(train_df)))

cat("\n--- Verification DB Summary ---\n")
cat("Samples:", nrow(verif_df), " | Features:", ncol(verif_df) - 1, "\n")
print(table(verif_df[[label_col]]))
# Out:
# --- Training DB Summary ---
# Samples: 869  | Features: 608
#
#   0   1
# 571 298
# Minority class ratio: 0.3429
#
# --- Verification DB Summary ---
# Samples: 2  | Features: 608
#
# 0 1
# 1 1

# %%
# ---------------------------
# Hyperparameter grid
# ---------------------------
p <- ncol(train_df) - 1
mtry_grid  <- sort(unique(pmax(1L, round(c(0.5*sqrt(p), sqrt(p), 2*sqrt(p))))))

ntree_grid <- c(1000, 2000, 4000, 8000)

cut_grid   <- list(
  c(0.7, 0.3),
  c(0.5, 0.5),
  c(0.3, 0.7)
)

results <- data.frame(
  ntree = integer(),
  mtry  = integer(),
  cutoff_0 = numeric(),
  cutoff_1 = numeric(),
  OOB_Error = numeric(),
  Accuracy = numeric(),
  Precision = numeric(),
  Recall = numeric(),
  F1 = numeric()
)

best <- list(oob = Inf)

# %%
# ---------------------------
# Grid Search with OOB + Accuracy Metrics (OOB-based)
# ---------------------------
for (nt in ntree_grid) {
  for (mt in mtry_grid) {
    for (co in cut_grid) {
      fit <- randomForest(
        as.formula(paste(label_col, "~ .")),
        data       = train_df,
        ntree      = nt,
        mtry       = mt,
        cutoff     = co,
        importance = FALSE
      )
      oob_err <- tail(fit$err.rate[,"OOB"], 1)

      pred <- fit$predicted

      cm <- confusionMatrix(data = pred, reference = train_df[[label_col]], positive="1")
      acc  <- cm$overall["Accuracy"]
      prec <- cm$byClass["Precision"]
      rec  <- cm$byClass["Recall"]
      f1   <- cm$byClass["F1"]

      results <- rbind(results, data.frame(
        ntree     = nt,
        mtry      = mt,
        cutoff_0  = co[1],
        cutoff_1  = co[2],
        OOB_Error = as.numeric(oob_err),
        Accuracy  = as.numeric(acc),
        Precision = as.numeric(prec),
        Recall    = as.numeric(rec),
        F1        = as.numeric(f1)
      ))

      if (oob_err < best$oob) {
        best <- list(model = fit, ntree = nt, mtry = mt, cutoff = co, oob = oob_err)
      }
    }
  }
}

cat("\nBest Hyperparameters (true global minimum OOB):\n")
print(list(
  ntree  = best$ntree,
  mtry   = best$mtry,
  cutoff = best$cutoff,
  OOB    = best$oob
))
# Out:
# Best Hyperparameters (true global minimum OOB):
# $ntree
# [1] 1000
#
# $mtry
# [1] 12
#
# $cutoff
# [1] 0.5 0.5
#
# $OOB
# [1] 0.003452244

# %%
# ---------------------------
# Accuracy metrics for best model (OOB-based)
# ---------------------------
print(best$model)

# OOB confusion matrix (raw counts; rows = truth, cols = predicted)
conf_mat <- best$model$confusion[1:2, 1:2]
cat("\n--- OOB Confusion Matrix (counts) ---\n")
print(conf_mat)

TN <- conf_mat[1,1]; FP <- conf_mat[1,2]
FN <- conf_mat[2,1]; TP <- conf_mat[2,2]

accuracy  <- (TP + TN) / sum(conf_mat)
precision <- TP / (TP + FP)
recall    <- TP / (TP + FN)
f1        <- 2 * precision * recall / (precision + recall)

fmt5 <- function(x) format(round(x + 1e-15, 5), nsmall = 5)

cat("\n--- OOB Accuracy Metrics (5 decimals) ---\n")
cat(sprintf("Accuracy : %s\n", fmt5(accuracy)))
cat(sprintf("Precision: %s\n", fmt5(precision)))
cat(sprintf("Recall   : %s\n", fmt5(recall)))
cat(sprintf("F1 Score : %s\n", fmt5(f1)))

oob_err_final <- tail(best$model$err.rate[, "OOB"], 1)
cat(sprintf("OOB Error: %s\n", fmt5(oob_err_final)))
# Out:
# Call:
#  randomForest(formula = as.formula(paste(label_col, "~ .")), data = train_df,      ntree = nt, mtry = mt, cutoff = co, importance = FALSE)
#                Type of random forest: classification
#                      Number of trees: 1000
# No. of variables tried at each split: 12
#
#         OOB estimate of  error rate: 0.35%
# Confusion matrix:
#     0   1 class.error
# 0 568   3  0.00525394
# 1   0 298  0.00000000
#
# --- OOB Confusion Matrix (counts) ---
#     0   1
# 0 568   3
# 1   0 298
#
# --- OOB Accuracy Metrics (5 decimals) ---
# Accuracy : 0.99655
# Precision: 0.99003
# Recall   : 1.00000
# F1 Score : 0.99499
# OOB Error: 0.00345

# %%
# ---------------------------
# Feature Ranking (final model retrained with ntree=8000)
# ---------------------------
final <- randomForest(
  as.formula(paste(label_col, "~ .")),
  data=train_df,
  ntree=8000,              # 8000 trees
  mtry=best$mtry,          # keep best mtry
  cutoff=best$cutoff,      # keep best cutoff
  importance=TRUE
)

imp <- importance(final, type=1)  # Mean Decrease Accuracy
imp_df <- data.frame(Feature=rownames(imp),
                     MDA=imp[,"MeanDecreaseAccuracy"])
imp_df <- imp_df[order(-imp_df$MDA), ]

cat("\nTop 10 Features (MDA, ntree=8000):\n")
print(head(imp_df, 10))
# Out:
# Top 10 Features (MDA, ntree=8000):
#             Feature      MDA
# TESPA1       TESPA1 32.59954
# SLC17A7     SLC17A7 29.77607
# LINC00507 LINC00507 28.05387
# KCNIP1       KCNIP1 27.17743
# ANKRD33B   ANKRD33B 26.98186
# SLIT3.1     SLIT3.1 26.86996
# SLIT3.2     SLIT3.2 26.65708
# SLIT3         SLIT3 26.47532
# SFTA1P       SFTA1P 26.30224
# NRGN           NRGN 26.12710

# %%
saveRDS(final, "modelBEST.rds")

# %%
# ---------------------------
# Run Time Predictions on Verification DB
# ---------------------------
modelBEST <- readRDS("modelBEST.rds")
verif_probs <- predict(modelBEST, newdata=verif_df, type="prob")
verif_preds <- predict(modelBEST, newdata=verif_df, type="response")

out <- data.frame(
  ID = rownames(verif_df),
  TrueLabel = verif_df[[label_col]],
  Predicted = verif_preds,
  Prob0 = verif_probs[, "0"],
  Prob1 = verif_probs[, "1"],
  stringsAsFactors = FALSE
)

cat("\nVerification Results:\n")
print(out)
# Out:
# Verification Results:
#   ID TrueLabel Predicted    Prob0    Prob1
# 1  1         1         1 0.028625 0.971375
# 2  2         0         0 0.944375 0.055625
